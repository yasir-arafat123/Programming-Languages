# %% [markdown]
# # Uploading to PyPI with Twine
#
# Publish your package to the world.
#
# ## 🎯 Learning Objectives
# - Create PyPI account.
# - Upload to TestPyPI first.
# - Publish to real PyPI.

# %% [markdown]
# ## 1. Create Accounts
#
# 1. **TestPyPI**: https://test.pypi.org/account/register/
# 2. **PyPI**: https://pypi.org/account/register/
#
# Create API tokens in account settings.

# %% [markdown]
# ## 2. Install Twine
#
# ```bash
# pip install twine
# ```

# %% [markdown]
# ## 3. Upload to TestPyPI First
#
# ```bash
# # Build
# python -m build
#
# # Upload to TestPyPI
# twine upload --repository testpypi dist/*
# ```
#
# Prompts for username (`__token__`) and password (your API token).

# %% [markdown]
# ## 4. Test Install from TestPyPI
#
# ```bash
# pip install --index-url https://test.pypi.org/simple/ mypackage
# ```
#
# If it works, ready for real PyPI!

# %% [markdown]
# ## 5. Upload to Real PyPI
#
# ```bash
# twine upload dist/*
# ```
#
# **⚠️ Warning**: You CANNOT delete or re-upload the same version number!

# %% [markdown]
# ## 6. Store Credentials Safely
#
# Create `~/.pypirc`:
# ```ini
# [pypi]
# username = __token__
# password = pypi-AgEIcHlwaS5vcmc...
#
# [testpypi]
# repository = https://test.pypi.org/legacy/
# username = __token__
# password = pypi-AgENdGVzdC5weXBpLm9...
# ```
#
# Now `twine upload` uses saved credentials.
