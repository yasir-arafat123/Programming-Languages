# %% [markdown]
# # Operator Precedence Overview
#
# PEMDAS for Python.
#
# ## 🎯 Learning Objectives
# - Default order.
# - Parentheses override.
# - Common gotchas.

# %% [markdown]
# ## 1. General Rules
#
# 1. `()` Parentheses
# 2. `**` Exponentiation
# 3. `*`, `/`, `//`, `%` (Multiplication/Division)
# 4. `+`, `-` (Addition/Subtraction)
# 5. `<<`, `>>` (Shifts)
# 6. `&` (Bitwise AND)
# 7. `^` (Bitwise XOR)
# 8. `|` (Bitwise OR)
# 9. `==`, `!=`, `>`, etc. (Comparisons)
# 10. `not`
# 11. `and`
# 12. `or`

# %% [markdown]
# ## 2. Gotcha: Exponentiation
#
# ```python
# print(-3**2)  # -9 (Because ** binds tighter than unary -)
# print((-3)**2) # 9
# ```
