# %% [markdown]
# # Boolean Operators
#
# Logic glue.
#
# ## 🎯 Learning Objectives
# - `and`.
# - `or`.
# - `not`.

# %% [markdown]
# ## 1. Truth Tables
#
# | A | B | `A and B` | `A or B` |
# | :--- | :--- | :--- | :--- |
# | T | T | T | T |
# | T | F | F | T |
# | F | T | F | T |
# | F | F | F | F |
