# %% [markdown]
# # Block Comments & Tags
#
# Writing paragraphs in code.
#
# ## 🎯 Learning Objectives
#
# - **Structure**: Indentation consistency.
# - **Style**: `#` vs Strings.
# - **Tags**: `TODO`, `FIXME`, `HACK`.
# - **IDE Integration**: How tools see these tags.

# %% [markdown]
# ## 1. Block Basics
#
# Block comments explain the *code that follows them*. They should handle the same indentation level as that code.
#
# Use a `#` for every line. Do NOT use docstrings (`"""`) for implementation comments (unless it's a module/function docstring).

# %%
def complex_algorithm():
    # This part of the algorithm implements the Fisher-Yates shuffle.
    # It walks through the list backwards and swaps each element
    # with a random element preceding it.
    #
    # Make sure to import 'random' first.
    pass

# %% [markdown]
# ## 2. Actionable Tags (TODO, FIXME)
#
# Most IDEs (VS Code, PyCharm) automatically highlight specific keywords in comments. This turns your code into a task list.

# %%
# TODO: Refactor this into a class
def messy_func():
    pass

# FIXME: Crashing on Unicode input
def parse_input():
    pass

# HACK: Temporary workaround for API bug #992
def api_call():
    pass

# NOTE: Do not change this timeout value
TIMEOUT = 10

# %% [markdown]
# ## 3. Pro Tip: Annotated TODOs
#
# In large teams, add your username/email to the TODO so people know who to blame/ask.

# %%
# TODO(Yasir): Optimize this loop using vectorization
