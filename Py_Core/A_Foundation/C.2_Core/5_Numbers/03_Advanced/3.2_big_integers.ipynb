# %% [markdown]
# # Big Integers
#
# Handling numbers bigger than 64 bits.
#
# ## 🎯 Learning Objectives
# - Automatic scaling.
# - Performance implications.
# - Limits (DoS protection).

# %% [markdown]
# ## 1. Unlimited Precision
#
# Python handles memory allocation for you.
#
# ```python
# x = 2 ** 1000
# print(len(str(x)))  # 302 digits
# ```

# %% [markdown]
# ## 2. Integer String Conversion Limit
#
# Recent Python versions (3.11+) limit string conversion to 4300 digits for security (DoS attacks).
#
# ```python
# import sys
# # sys.set_int_max_str_digits(10000)  # Increase limit if needed
# ```
