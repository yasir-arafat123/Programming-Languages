# %% [markdown]
# # Numeric Performance Tips
#
# Python is slow at loops. How to number crunch efficiently.
#
# ## 🎯 Learning Objectives
# - Python's overhead.
# - When to use `numpy`.
# - Bitwise operators.

# %% [markdown]
# ## 1. The Overhead
#
# Every integer in Python is an object.
# Adding 1 million integers involves millions of object allocations/checks.
#
# **Solution**: Use NumPy for math-heavy tasks.
#
# ```python
# # import numpy as np
# # arr = np.array([1, 2, 3])
# # arr * 2  # Vectorized (C speed)
# ```

# %% [markdown]
# ## 2. Bitwise Operators
#
# Fast operations for flags/masks.
#
# - `&` (AND)
# - `|` (OR)
# - `^` (XOR)
# - `<<` (Left Shift)
# - `>>` (Right Shift)
