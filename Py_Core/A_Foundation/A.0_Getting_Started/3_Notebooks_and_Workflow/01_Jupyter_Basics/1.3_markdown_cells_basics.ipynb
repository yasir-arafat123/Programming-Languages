# %% [markdown]
# # Markdown Basics
#
# Great analysis needs specific narrative. Markdown is a lightweight markup language used for formatting.
#
# ## 🎯 Learning Objectives
# - Headers & Text Styles.
# - Lists & Links.
# - Mathematical Formulas (LaTeX).

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
#
# **Bold**, *Italic*, `Monospace`.
#
# > Blockquotes are cool for emphasis.

# %% [markdown]
# ## Lists
#
# 1.  Ordered Item 1
# 2.  Ordered Item 2
#
# - Unordered Item
# - Another Item
#     - Nested Item

# %% [markdown]
# ## LaTeX Math
#
# Use dollar signs `$ ` for inline math: $E = mc^2$
#
# Use double dollar signs `$$` for block math:
#
# $$
# \int_{a}^{b} x^2 dx
# $$

# %% [markdown]
# ## Code Blocks
#
# ```python
# def syntax_highlighting():
#     return True
# ```
